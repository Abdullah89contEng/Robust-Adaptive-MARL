# %%
import torch

# %%
x = torch.tensor([1,2,3],dtype=torch.float64,requires_grad= True)
y = 3 * x**3
z = torch.sin(y) + y + 1
o = z.sum()

# %%
o.backward()

# %%
b = torch.tensor([[1,2,3],[4,5,6]])

# %%
print(b.numel())
# Out:
# 6

# %%
type(x)
# Out:
# int
